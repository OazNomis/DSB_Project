# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load Data</a></span></li><li><span><a href="#Preliminary-feature-selection" data-toc-modified-id="Preliminary-feature-selection-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Preliminary feature selection</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import joblib
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6)
sns.set(style = "whitegrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
warnings.filterwarnings(action="ignore")

# %% [markdown]
# ## Load Data

# %%
accepted = pd.read_csv('../data/accepted_2007_to_2018Q4.csv')

# %%
# Parse Years
accepted['year'] = pd.to_datetime(accepted.issue_d).dt.year
# Bin late loans into one group
accepted.loan_status = accepted.loan_status.apply(lambda x: np.where(x == 'Late (31-120 days)','Late',x))
accepted.loan_status = accepted.loan_status.apply(lambda x: np.where(x == 'In Grace Period','Late',x))
accepted.loan_status = accepted.loan_status.apply(lambda x: np.where(x == 'Late (16-30 days)','Late',x))
# Reduce the size of the dataset
accepted = accepted[(accepted.year.isin([2016,2017,2018]))& 
                    accepted.loan_status.isin(['Fully Paid','Charged Off','Late'])]

# %%
print(accepted.shape)
accepted.head()
# Out:
# (550097, 152)
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 421101  130956066        NaN     3000.0       3000.0           3000.0
# 421113  130968727        NaN     5000.0       5000.0           5000.0
# 421120  130910225        NaN     7000.0       7000.0           7000.0
# 421121  130962380        NaN    20300.0      20300.0          20300.0
# 421135  130966492        NaN    30000.0      30000.0          30000.0
#
#               term  int_rate  installment grade sub_grade  \
# 421101   36 months      7.34        93.10     A        A4
# 421113   36 months     11.98       166.03     B        B5
# 421120   36 months     11.98       232.44     B        B5
# 421121   60 months     17.47       509.66     D        D1
# 421135   36 months     21.85      1143.39     D        D5
#
#                        emp_title emp_length home_ownership  annual_inc  \
# 421101          Scale Technician    9 years           RENT     52000.0
# 421113            SDO Supervisor  10+ years            OWN     55000.0
# 421120                    Parole   < 1 year       MORTGAGE     40000.0
# 421121  Administrative Assistant   < 1 year           RENT     55000.0
# 421135                   teacher  10+ years            OWN     57000.0
#
#        verification_status   issue_d loan_status pymnt_plan  \
# 421101     Source Verified  Mar-2018  Fully Paid          n
# 421113        Not Verified  Mar-2018  Fully Paid          n
# 421120            Verified  Mar-2018  Fully Paid          n
# 421121            Verified  Mar-2018        Late          n
# 421135            Verified  Mar-2018  Fully Paid          n
#
#                                                       url desc  \
# 421101  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421113  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421120  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421121  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421135  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                    purpose                    title zip_code addr_state  \
# 421101      major_purchase           Major purchase    988xx         WA
# 421113               other                    Other    300xx         GA
# 421120    home_improvement         Home improvement    797xx         TX
# 421121         credit_card  Credit card refinancing    112xx         NY
# 421135  debt_consolidation       Debt consolidation    341xx         FL
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 421101   0.58          0.0         Jan-1998           760.0            764.0
# 421113  14.18          0.0         Aug-2001           675.0            679.0
# 421120  20.25          0.0         Mar-2007           695.0            699.0
# 421121  26.63          0.0         Nov-2007           705.0            709.0
# 421135  27.58          0.0         Apr-2000           680.0            684.0
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 421101             0.0                    26.0                     NaN
# 421113             0.0                    74.0                    82.0
# 421120             0.0                    60.0                     NaN
# 421121             0.0                     NaN                     NaN
# 421135             1.0                    68.0                     NaN
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 421101       7.0      0.0      141.0         0.5       30.0
# 421113      14.0      1.0    11449.0        33.9       24.0
# 421120      13.0      0.0     5004.0        36.0       29.0
# 421121      10.0      0.0    17506.0        70.9       26.0
# 421135      11.0      0.0    29222.0        53.2       26.0
#
#        initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 421101                   w       0.00           0.00   3011.577285
# 421113                   w       0.00           0.00   5013.306667
# 421120                   w       0.00           0.00   7693.314943
# 421121                   w   18497.12       18497.12   4037.880000
# 421135                   w       0.00           0.00  34389.550341
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 421101          3011.58          3000.00          11.58                 0.0
# 421113          5013.31          5000.00          13.31                 0.0
# 421120          7693.31          7000.00         693.31                 0.0
# 421121          4037.88          1802.88        2235.00                 0.0
# 421135         34389.55         30000.00        4389.55                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 421101         0.0                      0.0     May-2018           614.03
# 421113         0.0                      0.0     Apr-2018          5019.97
# 421120         0.0                      0.0     Mar-2019          5364.25
# 421121         0.0                      0.0     Dec-2018           509.66
# 421135         0.0                      0.0     Dec-2018         26458.65
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 421101          NaN           Nov-2018                 764.0
# 421113          NaN           Aug-2018                 679.0
# 421120          NaN           Mar-2019                 644.0
# 421121     Apr-2019           Mar-2019                 704.0
# 421135          NaN           Dec-2018                 699.0
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 421101                760.0                         0.0
# 421113                675.0                         0.0
# 421120                640.0                         0.0
# 421121                700.0                         0.0
# 421135                695.0                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 421101                          NaN          1.0       Individual
# 421113                         74.0          1.0       Individual
# 421120                         60.0          1.0       Individual
# 421121                          NaN          1.0       Individual
# 421135                         68.0          1.0       Individual
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 421101               NaN        NaN                       NaN             0.0
# 421113               NaN        NaN                       NaN             0.0
# 421120               NaN        NaN                       NaN             0.0
# 421121               NaN        NaN                       NaN             0.0
# 421135               NaN        NaN                       NaN             0.0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 421101           0.0     150592.0          0.0          0.0          1.0
# 421113           0.0      28880.0          1.0          1.0          0.0
# 421120           0.0     131726.0          1.0          6.0          0.0
# 421121           0.0      60594.0          0.0          3.0          0.0
# 421135           0.0     157566.0          1.0          1.0          2.0
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 421101          2.0                 7.0           0.0      NaN          0.0
# 421113          0.0                33.0       17431.0     63.0          2.0
# 421120          2.0                16.0      126722.0    102.0          2.0
# 421121          1.0                24.0       43088.0     74.0          0.0
# 421135          2.0                 6.0       33030.0     94.0          2.0
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 421101          1.0       141.0       1.0           31000.0     1.0
# 421113          2.0      4829.0      47.0           33800.0     0.0
# 421120          2.0      3944.0      90.0           13900.0     2.0
# 421121          1.0      8215.0      69.0           24700.0     0.0
# 421135          2.0      6236.0      69.0           55500.0     2.0
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 421101          2.0           2.0                   3.0      25099.0
# 421113          1.0           1.0                   2.0       2222.0
# 421120          1.0           4.0                   4.0      10977.0
# 421121          1.0           0.0                   3.0       6733.0
# 421135          8.0           5.0                   5.0      14324.0
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 421101         30359.0      0.5                       0.0          0.0
# 421113         10551.0     52.0                       0.0          0.0
# 421120          4996.0     50.0                       0.0          0.0
# 421121          7194.0     70.9                       0.0          0.0
# 421135         19752.0     33.5                       0.0          0.0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 421101               132.0                 242.0                   18.0
# 421113                77.0                 199.0                    3.0
# 421120               122.0                 132.0                    1.0
# 421121               124.0                 111.0                   22.0
# 421135               195.0                 215.0                   11.0
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 421101             7.0       4.0                  18.0
# 421113             3.0       0.0                   3.0
# 421120             1.0       0.0                  10.0
# 421121            22.0       0.0                  22.0
# 421135             6.0       2.0                  11.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 421101                       NaN                    7.0
# 421113                       NaN                   12.0
# 421120                      64.0                    5.0
# 421121                       NaN                    NaN
# 421135                       NaN                    0.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 421101                             NaN                    0.0             1.0
# 421113                             NaN                    1.0             3.0
# 421120                            60.0                    3.0             2.0
# 421121                             NaN                    0.0             3.0
# 421135                             NaN                    1.0             3.0
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 421101              1.0          4.0       15.0        7.0            6.0
# 421113              3.0          4.0        7.0        6.0           13.0
# 421120              2.0          3.0        4.0       19.0            7.0
# 421121              3.0          6.0        8.0       14.0            6.0
# 421135              4.0          6.0        7.0       10.0            9.0
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 421101           19.0                  1.0       7.0               0.0
# 421113           18.0                  3.0      14.0               0.0
# 421120           10.0                  2.0      13.0               0.0
# 421121           11.0                  3.0      10.0               0.0
# 421135           14.0                  4.0      11.0               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 421101           0.0                 0.0                 1.0            96.7
# 421113           0.0                 0.0                 2.0            95.7
# 421120           0.0                 0.0                 2.0            89.7
# 421121           0.0                 0.0                 0.0           100.0
# 421135           0.0                 0.0                 5.0            96.0
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 421101               0.0                   0.0        0.0         191216.0
# 421113              33.3                   1.0        0.0          61551.0
# 421120              33.3                   0.0        0.0         132817.0
# 421121              60.0                   0.0        0.0          87959.0
# 421135              33.3                   0.0        0.0         188780.0
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 421101              141.0         30500.0                         0.0
# 421113            28880.0         22000.0                     27751.0
# 421120           131726.0         10000.0                    118917.0
# 421121            60594.0         24700.0                     58404.0
# 421135            62252.0         29400.0                     35000.0
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 421101              NaN                     NaN                      NaN
# 421113              NaN                     NaN                      NaN
# 421120              NaN                     NaN                      NaN
# 421121              NaN                     NaN                      NaN
# 421135              NaN                     NaN                      NaN
#
#        sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 421101                      NaN                     NaN               NaN
# 421113                      NaN                     NaN               NaN
# 421120                      NaN                     NaN               NaN
# 421121                      NaN                     NaN               NaN
# 421135                      NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 421101               NaN                 NaN                  NaN
# 421113               NaN                 NaN                  NaN
# 421120               NaN                 NaN                  NaN
# 421121               NaN                 NaN                  NaN
# 421135               NaN                 NaN                  NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 421101                    NaN                               NaN
# 421113                    NaN                               NaN
# 421120                    NaN                               NaN
# 421121                    NaN                               NaN
# 421135                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 421101                                 NaN
# 421113                                 NaN
# 421120                                 NaN
# 421121                                 NaN
# 421135                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 421101                                  NaN             N           NaN
# 421113                                  NaN             N           NaN
# 421120                                  NaN             N           NaN
# 421121                                  NaN             N           NaN
# 421135                                  NaN             N           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 421101             NaN             NaN            NaN              NaN
# 421113             NaN             NaN            NaN              NaN
# 421120             NaN             NaN            NaN              NaN
# 421121             NaN             NaN            NaN              NaN
# 421135             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 421101                 NaN               NaN                     NaN
# 421113                 NaN               NaN                     NaN
# 421120                 NaN               NaN                     NaN
# 421121                 NaN               NaN                     NaN
# 421135                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 421101              NaN           NaN                  NaN
# 421113              NaN           NaN                  NaN
# 421120              NaN           NaN                  NaN
# 421121              NaN           NaN                  NaN
# 421135              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 421101                                         NaN
# 421113                                         NaN
# 421120                                         NaN
# 421121                                         NaN
# 421135                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 421101                             NaN                           NaN
# 421113                             NaN                           NaN
# 421120                             NaN                           NaN
# 421121                             NaN                           NaN
# 421135                             NaN                           NaN
#
#        disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 421101                Cash                    N                       NaN
# 421113                Cash                    N                       NaN
# 421120                Cash                    N                       NaN
# 421121                Cash                    N                       NaN
# 421135                Cash                    N                       NaN
#
#        settlement_status settlement_date  settlement_amount  \
# 421101               NaN             NaN                NaN
# 421113               NaN             NaN                NaN
# 421120               NaN             NaN                NaN
# 421121               NaN             NaN                NaN
# 421135               NaN             NaN                NaN
#
#         settlement_percentage  settlement_term    year
# 421101                    NaN              NaN  2018.0
# 421113                    NaN              NaN  2018.0
# 421120                    NaN              NaN  2018.0
# 421121                    NaN              NaN  2018.0
# 421135                    NaN              NaN  2018.0

# %% [markdown]
# ## Preliminary feature selection

# %%
accepted.groupby(['loan_status','pymnt_plan']).size()
# Out:
# loan_status  pymnt_plan
# Charged Off  n             116257
# Fully Paid   n             402449
# Late         n              30818
#              y                573
# dtype: int64

# %%
accepted.title.nunique()
# Out:
# 13

# %%
'loan_amnt','funded_amnt','funded_amnt_inv','term','int_rate','installment','grade','sub_grade','emp_length',
'home_ownership','annual_inc','verification_status','issue_d','year','loan_status','purpose','addr_state','dti',
'earliest_cr_line',
'inq_last_6mths',
'open_acc',
'pub_rec',
'revol_bal',
'revol_util',
'total_acc',
'out_prncp',
'out_prncp_inv',
'total_pymnt',
'total_pymnt_inv',
'total_rec_prncp',
'total_rec_int',
'loan_status'
